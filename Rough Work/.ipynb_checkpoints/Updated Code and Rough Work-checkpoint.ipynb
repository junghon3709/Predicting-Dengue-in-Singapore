# %%
import pandas as pd
import datetime
import numpy as np
import sklearn
import copy
import tensorflow as tf
import keras
import matplotlib.pyplot as pl
import io 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the datasets

# %%
# please load your own path here
combined_df=pd.read_csv(r'/Users/yipjh/Desktop/Projects/Predicting-Dengue-in-Singapore/Data/post-processed/combined_data_030120.csv')
dengue_df=pd.read_csv(r'/Users/yipjh/Desktop/Projects/Predicting-Dengue-in-Singapore/Data/post-processed/dengue_271219.csv')
pop_df=pd.read_csv(r'/Users/yipjh/Desktop/Projects/Predicting-Dengue-in-Singapore/Data/post-processed/population-sg.csv')

# %% [markdown]
# ### Cleaning the data

# %%
pop_dict={}
for i, j in pop_df.iterrows():
    pop_dict.update({j[0]:int(j[1].replace(',',''))})

pop_df['population']=pop_dict.values()

oo=pd.date_range('1/2/2000', periods=7273)
date_list=oo.to_pydatetime().tolist()

op=dengue_df['Unnamed: 0']
def foo(st):
 y=st.split('-')
 return datetime.datetime(int(y[0]), int(y[1]), int(y[2]))

dt_list=list(map(foo, op))
oo=oo.to_pydatetime().tolist()
combined_df.index=oo

combined_df.drop(['Unnamed: 0'], axis=1, inplace=True)
dengue_df.drop(['Unnamed: 0'], axis=1, inplace=True)

dengue_df.index=dt_list

# %%
# to get rid of duplicates in the dengue dataset
def rid_duplicates(df):
    return df.loc[~df.index.duplicated(keep='first')]

trancated_dengue=rid_duplicates(dengue_df)

# %%
# we want to normalise the data first
def normaliser(df, *args):
    _=copy.copy(df)
    for i in args:
        ran=_[i].max()-_[i].min()
        std=_[i].std()
        ave=_[i].mean()
        _[i]=(_[i]-ave)/std
    return _

# %%
trancated_dengue=normaliser(trancated_dengue, 'dengue')
combined_df=normaliser(combined_df, 'rain_mean', 'temp_mean')
pop_df=normaliser(pop_df, 'population')

# %%
def pull_dataframe(date, x, iu, *args, **kwargs):
    idx=date_list.index(date)
    u=pd.DataFrame()
    if idx-x-iu>=0:
        for i, text in zip(args, kwargs.values()):
            o=i[idx-x-iu:idx-iu][text]
            u[text]=o
        return u, date
    else:
        return u, date

# %%
rainfall_df=pd.DataFrame(combined_df['rain_mean'])
temperature_df=pd.DataFrame(combined_df['temp_mean'])

# %% [markdown]
# ### Setting parameters of our inputs
# `DATA_WINDOW` refers to the number of weeks of data considered when making the prediction of dengue cases.
#
# `LEAD_TIME` refers to how many weeks in the future we are doing our dengue prediction.
#
# `MAX_EXTRACT` and `LCD` will be dealt with below.

# %%
DATA_WINDOW=18 #should be even
LEAD_TIME=8
MAX_EXTRACT=20 # rainfall window
LCD=6 #should divide DATA_WINDOW or 7, increase to reduce noise

# %%
rf_df=pd.DataFrame()
tp_df=pd.DataFrame()

for date in trancated_dengue.index:
    df_pushback, dat=pull_dataframe(date, DATA_WINDOW*7, LEAD_TIME*7, rainfall_df, temperature_df, label1='rain_mean', label2='temp_mean')
    if len(df_pushback)!=0:
        rf_df[dat]=df_pushback['rain_mean'].values
        tp_df[dat]=df_pushback['temp_mean'].values

# %%
combined_df
# Out:
#             temp_mean  rain_mean
# 2000-01-02  -0.760997   0.121343
# 2000-01-03  -0.760997  -0.310010
# 2000-01-04  -0.307704  -0.538921
# 2000-01-05  -2.536395   3.938065
# 2000-01-06  -2.513730  -0.405151
# ...               ...        ...
# 2019-11-26   0.683497  -0.573774
# 2019-11-27   0.103282  -0.387625
# 2019-11-28   0.212504   0.558220
# 2019-11-29  -0.940155   3.880446
# 2019-11-30  -0.117752   0.101158
#
# [7273 rows x 2 columns]

# %% [markdown]
# For instance, to do prediction on the dengue cases in 2000-06-19, rainfall and temperature data from 8-26 weeks back are used. This gives us a 112 days of rainfall and temperature data, which are indexed 0-111 down the columns in both the `rf_df` and `tp_df` dataframe.

# %% [markdown]
# ### Noise Reduction
#
# The rainfall daily and temperature data are noisy. As explained in the medium article, we will be focusing on the maximum $n$ days, as well as other metrics (such as mean and std) to reduce the noise.
#
# `MAX_EXTRACT`=$n$. Takes out the maximum $n$ rainfall/temperature data down each column.
#
# `LCD`=$d$. Takes an interval of $d$ days from the `DATA_WINDOW*7=112` days and averages it.

# %%
def extract_max(df, n , label):
  size=np.argsort(df.values, axis=0)[-n:].T.shape
  ref=np.argsort(df.values, axis=0)[-n:]
  # rainfall_values=rf_df.values.T
  maximum_values=np.zeros((size[0], n))

  for i in range(size[0]):
    for j in range(n):
      pos=ref.T[i][j]
      val=df.values[pos][i]
      maximum_values[i, j]=val

  columns_list=[]
  for i in range(1, n+1):
    columns_list.append(label+str(i))

  maximum_df=pd.DataFrame(maximum_values, columns=columns_list)
  return maximum_df

maximum_rainfall_df=extract_max(rf_df, MAX_EXTRACT, 'rainfallmax')
maximum_temperature_df=extract_max(tp_df, MAX_EXTRACT, 'temperaturemax')

# %%
def seven_day_mean(n, d, **kwargs): # where d should be a divisor of n, chooose d smaller for more 'rugged' data
    a=pd.DataFrame()
    for j, df in zip(kwargs.keys(), kwargs.values()):
        for i in range(0, n , d):
            label=str(j)+str( i)
            a[label]=df[i:i+d].mean(axis=0)
    return a

# %%
df_seven_day_mean=seven_day_mean(DATA_WINDOW*7, LCD, mean_rain=rf_df, mean_temp=tp_df)

# %%
rf_df.tail()
# Out:
#      2000-07-03  2000-07-10  2000-07-17  2000-07-24  2000-07-31  2000-08-07  \
# 121    1.183987   -0.561454   -0.592214   -0.023515   -0.592214   -0.374391
# 122   -0.518176    0.105605   -0.009208    0.577375   -0.035676   -0.534986
# 123    0.142803   -0.592214   -0.581126   -0.310726    0.921098   -0.592214
# 124   -0.299638   -0.592214   -0.554301    0.251893    0.010822    0.020479
# 125   -0.592214   -0.538205   -0.592214   -0.591856   -0.384049    0.230075
#
#      2000-08-14  2000-08-21  2000-08-28  2000-09-04  ...  2019-09-23  \
# 121   -0.528548   -0.422319   -0.529621   -0.572542  ...   -0.179041
# 122    0.236513   -0.588279   -0.576119   -0.592214  ...   -0.592214
# 123   -0.586133   -0.371172   -0.502080   -0.476686  ...   -0.592214
# 124    2.267735   -0.471678   -0.063216   -0.549651  ...   -0.591896
# 125    0.168198   -0.588637   -0.591856   -0.592214  ...   -0.586809
#
#      2019-09-30  2019-10-07  2019-10-14  2019-10-21  2019-10-28  2019-11-04  \
# 121   -0.592214   -0.542815   -0.466949   -0.549929   -0.494063    0.735026
# 122   -0.592214   -0.592214   -0.591896   -0.592214   -0.588240   -0.578225
# 123   -0.592214   -0.592214   -0.592214   -0.592214    0.463965   -0.592214
# 124   -0.592214   -0.591578   -0.370970   -0.592214   -0.592214   -0.592214
# 125   -0.588165   -0.592214   -0.592214   -0.552047   -0.591260   -0.592214
#
#      2019-11-11  2019-11-18  2019-11-25
# 121   -0.592214   -0.592214    2.543638
# 122   -0.592214   -0.592214   -0.590194
# 123   -0.592214   -0.589988   -0.402553
# 124   -0.492571   -0.592214   -0.527914
# 125   -0.591884   -0.592214    1.180816
#
# [5 rows x 1009 columns]

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')


plt.plot(list(combined_df['rain_mean']), label='rain_mean')
plt.legend()
plt.show()

# %%
# for rainfall/temp metrics such as max, min, std, med
mean_df=pd.DataFrame()

mean_df['temp_mean']=list(tp_df.mean(axis=0))
mean_df['temp_std']=list(tp_df.std(axis=0))
mean_df['temp_min']=list(tp_df.min(axis=0))
mean_df['temp_max']=list(tp_df.max(axis=0))
mean_df['temp_med']=list(tp_df.median(axis=0))

mean_df['rain_mean']=list(rf_df.mean(axis=0))
mean_df['rain_std']=list(rf_df.std(axis=0))
mean_df['rain_min']=list(rf_df.min(axis=0))
mean_df['rain_max']=list(rf_df.max(axis=0))
mean_df['rain_med']=list(rf_df.median(axis=0))

# %%
mean_df=mean_df.merge(maximum_rainfall_df, left_index=True, right_index=True)
mean_df=mean_df.merge(maximum_temperature_df, left_index=True, right_index=True)

# %%
indexes=df_seven_day_mean.index
df_seven_day_mean.reset_index(drop=True, inplace=True)
mean_df.reset_index(drop=True, inplace=True)

# %%
def merge(a, b):
    indexes=a.index
    a.reset_index(drop=True, inplace=True)
    b.reset_index(drop=True, inplace=True)
    for col in b.columns:
        a[col]=b[col]
    a.index=indexes
    return a

mean_df=merge(mean_df, df_seven_day_mean)
mean_df.index=indexes
combined_Data=mean_df

# %%
dengue_append=trancated_dengue[trancated_dengue.index>=combined_Data.index[0]]

# %%
combined_Data['dengue_actual']=dengue_append['dengue']

# %%
dengue_append.head(1)
# Out:
#               dengue
# 2000-07-03 -0.973785

# %%
trancated_dengue.head(27)
# Out:
#               dengue
# 2000-01-03 -0.946154
# 2000-01-10 -0.994508
# 2000-01-17 -0.959970
# 2000-01-24 -0.959970
# 2000-01-31 -0.973785
# 2000-02-07 -0.932339
# 2000-02-14 -1.029047
# 2000-02-21 -0.953062
# 2000-02-28 -0.966878
# 2000-03-06 -0.987601
# 2000-03-13 -1.042862
# 2000-03-20 -0.980693
# 2000-03-27 -1.022139
# 2000-04-03 -1.035955
# 2000-04-10 -1.008324
# 2000-04-17 -1.008324
# 2000-04-24 -0.980693
# 2000-05-01 -0.987601
# 2000-05-08 -1.015231
# 2000-05-15 -0.973785
# 2000-05-22 -1.015231
# 2000-05-29 -1.001416
# 2000-06-05 -0.966878
# 2000-06-12 -0.994508
# 2000-06-19 -0.987601
# 2000-06-26 -0.918524
# 2000-07-03 -0.973785

# %%
dengue_process
# Out:
#             -8        -9       -10       -11       -12       -13       -14  \
# 26   -1.015231 -0.987601 -0.980693 -1.008324 -1.008324 -1.035955 -1.022139
# 27   -0.973785 -1.015231 -0.987601 -0.980693 -1.008324 -1.008324 -1.035955
# 28   -1.015231 -0.973785 -1.015231 -0.987601 -0.980693 -1.008324 -1.008324
# 29   -1.001416 -1.015231 -0.973785 -1.015231 -0.987601 -0.980693 -1.008324
# 30   -0.966878 -1.001416 -1.015231 -0.973785 -1.015231 -0.987601 -0.980693
# ...        ...       ...       ...       ...       ...       ...       ...
# 1030  1.796202  2.224479  2.556049  2.549141  3.081034  3.115572  3.405696
# 1031  1.215955  1.796202  2.224479  2.556049  2.549141  3.081034  3.115572
# 1032  1.133063  1.215955  1.796202  2.224479  2.556049  2.549141  3.081034
# 1033  1.015632  1.133063  1.215955  1.796202  2.224479  2.556049  2.549141
# 1034  0.739324  1.015632  1.133063  1.215955  1.796202  2.224479  2.556049
#
#            -15       -16       -17  ...      ave6      ave8     ave10  \
# 26   -0.980693 -1.042862 -0.987601  ... -1.006021 -1.004870 -1.006942
# 27   -1.022139 -0.980693 -1.042862  ... -0.995660 -1.004006 -1.005561
# 28   -1.035955 -1.022139 -0.980693  ... -0.996811 -1.003143 -1.002798
# 29   -1.008324 -1.035955 -1.022139  ... -0.995660 -0.998826 -1.004870
# 30   -1.008324 -1.008324 -1.035955  ... -0.993357 -0.993645 -0.999344
# ...        ...       ...       ...  ...       ...       ...       ...
# 1030  3.523126  3.032680  2.369541  ...  2.553746  2.781412  2.765352
# 1031  3.405696  3.523126  3.032680  ...  2.237143  2.493016  2.649993
# 1032  3.115572  3.405696  3.523126  ...  1.912481  2.208937  2.460032
# 1033  3.081034  3.115572  3.405696  ...  1.656897  1.946444  2.209282
# 1034  2.549141  3.081034  3.115572  ...  1.354109  1.653731  1.942645
#
#          ave12     ave14     ave16     ave18     trend  strong_trend  \
# 26   -0.999113 -0.996482 -0.992781 -0.991054  0.001151      0.000576
# 27   -1.000840 -0.999442 -0.993645 -0.989903  0.000768      0.000256
# 28   -1.004870 -0.998456 -0.996235 -0.992973  0.003070      0.000085
# 29   -1.006021 -1.001909 -1.000553 -0.995276  0.001535      0.000725
# 30   -0.999689 -1.001909 -0.996667 -0.994892  0.001919     -0.000597
# ...        ...       ...       ...       ...       ...           ...
# 1030  2.645273  2.510655  2.360474  2.164612 -0.084427      0.008571
# 1031  2.566410  2.475623  2.369541  2.216804 -0.016502      0.039485
# 1032  2.500211  2.435164  2.343637  2.228700 -0.003454      0.058566
# 1033  2.387386  2.353258  2.300464  2.225630  0.029550      0.063960
# 1034  2.196273  2.268392  2.240453  2.180730  0.053727      0.072403
#
#       dengue_std
# 26      0.257710
# 27      0.257207
# 28      0.258101
# 29      0.258546
# 30      0.257804
# ...          ...
# 1030    0.934552
# 1031    0.867807
# 1032    0.860318
# 1033    0.864566
# 1034    0.904650
#
# [1009 rows x 30 columns]

# %%
rf_df.head()
# Out:
#    2000-07-03  2000-07-10  2000-07-17  2000-07-24  2000-07-31  2000-08-07  \
# 0   -0.310010   -0.073947    3.517442    0.041939    0.111685    0.490103
# 1   -0.538921   -0.314302   -0.212366    4.049301    0.213264   -0.090042
# 2    3.938065    2.648656   -0.458087   -0.573973   -0.449145    0.259404
# 3   -0.405151   -0.492423   -0.591141   -0.558235   -0.546432   -0.403721
# 4   -0.575761   -0.546789   -0.592214   -0.465956   -0.592214    0.246886
#
#    2000-08-14  2000-08-21  2000-08-28  2000-09-04  ...  2019-09-23  \
# 0    0.227571    0.522293   -0.196628   -0.586133  ...    0.252010
# 1   -0.570038    2.154710   -0.592214   -0.592214  ...   -0.590112
# 2   -0.592214   -0.014215   -0.399428   -0.592214  ...   -0.590462
# 3    0.174636    0.164979   -0.529979   -0.554301  ...    1.009691
# 4    0.553053   -0.351143   -0.559308   -0.592214  ...   -0.590840
#
#    2019-09-30  2019-10-07  2019-10-14  2019-10-21  2019-10-28  2019-11-04  \
# 0    1.610257   -0.547973   -0.587407   -0.453151    0.010320   -0.592214
# 1   -0.563263    0.056646   -0.497445    1.280273   -0.480978   -0.318208
# 2    1.997964    0.077174   -0.522840   -0.242273   -0.591184    4.154639
# 3    0.348608   -0.168014   -0.475613    0.077540   -0.294688   -0.587063
# 4   -0.256717   -0.497252   -0.065778    3.550218   -0.434437    0.905455
#
#    2019-11-11  2019-11-18  2019-11-25
# 0    0.084418   -0.493584   -0.467996
# 1    0.090138   -0.465028   -0.544075
# 2    0.093992   -0.088903   -0.105665
# 3    0.078780   -0.561311    0.755671
# 4    0.226825   -0.592214   -0.371709
#
# [5 rows x 1009 columns]

# %%
rf_df.shape
# Out:
# (126, 1009)

# %%
combined_df
# Out:
#             temp_mean  rain_mean
# 2000-01-02  -0.760997   0.121343
# 2000-01-03  -0.760997  -0.310010
# 2000-01-04  -0.307704  -0.538921
# 2000-01-05  -2.536395   3.938065
# 2000-01-06  -2.513730  -0.405151
# ...               ...        ...
# 2019-11-26   0.683497  -0.573774
# 2019-11-27   0.103282  -0.387625
# 2019-11-28   0.212504   0.558220
# 2019-11-29  -0.940155   3.880446
# 2019-11-30  -0.117752   0.101158
#
# [7273 rows x 2 columns]

# %% [markdown]
# ### Adding population data

# %%
pop_df=pop_df[pop_df['year']>=2000]
a=[]
for i in combined_Data.index:
    a.append(pop_dict[i.year])

combined_Data['population']=a

# %% [markdown]
# ### Adding past dengue data
#
# This section adds past dengue data prior to the actual date which we wish to predict. For instance, if we wish to predict dengue cases in week $26$ with a lead time of $8$, dengue cases from week $1-18$ are included.

# %%
def shift(df, data_window, lead_time):
  dengue_shift=pd.DataFrame()
  for i in range(lead_time, data_window+lead_time):
      dengue_shift[-i]=list(df['dengue'].shift(i))
  dengue_shift=dengue_shift.dropna()
  return dengue_shift

# %%
dengue_shift=shift(trancated_dengue, DATA_WINDOW, LEAD_TIME)[1:]

# %%
# here, -8 indicates the most recent data and -25 incidcates the most outdated data, ie 18 weeks before week -8. 
# The week which we wish to predict is considered week 0 which corresponds to a lead time of 8.
dengue_shift.shape
# Out:
# (1009, 18)

# %% [markdown]
# This averages specific columns from the `dengue_shift` dataframe. `ave2` takes in the 2 most recent data entries and averages them. (ie. from -8 to -9). `ave4` takes in the 4 most recent entries and does the same. (ie. from -8 to -11). This tries to reduce noise in the dengue dataset without completely getting rid of it.

# %%
def average_last_n_cols(df, *args):
  df_average=pd.DataFrame()
  c= copy.copy(df)
  for n in args:
    f=c[c.columns[0:n]]
    average_n=f.mean(axis=1)
    label='ave' + str(n)
    df_average[label]=average_n
  return df_average

# %%
ave_intevals=list(np.arange(2, DATA_WINDOW+2, 2))
dengue_average=average_last_n_cols(dengue_shift, *ave_intevals)

# %%
dengue_average.head()
# Out:
#         ave2      ave4      ave6      ave8     ave10     ave12     ave14  \
# 26 -1.001416 -0.997962 -1.006021 -1.004870 -1.006942 -0.999113 -0.996482
# 27 -0.994508 -0.989328 -0.995660 -1.004006 -1.005561 -1.000840 -0.999442
# 28 -0.994508 -0.997962 -0.996811 -1.003143 -1.002798 -1.004870 -0.998456
# 29 -1.008324 -1.001416 -0.995660 -0.998826 -1.004870 -1.006021 -1.001909
# 30 -0.984147 -0.989328 -0.993357 -0.993645 -0.999344 -0.999689 -1.001909
#
#        ave16     ave18
# 26 -0.992781 -0.991054
# 27 -0.993645 -0.989903
# 28 -0.996235 -0.992973
# 29 -1.000553 -0.995276
# 30 -0.996667 -0.994892

# %%
dengue_process=merge(dengue_shift, dengue_average)

# %% [markdown]
# ### Adding dengue trends
#
# `trend` is simply: (last week-first week)/DATA_WINDOW, and in our case: `(week[-8]-week[-25])/DATA_WINDOW)`.
#
# `strong_trend` takes: (ave2-ave(DATA_WINDOW))/DATA_WINDOW, and in our case: `(ave2-ave18)/DATA_WINDOW)`.

# %%
def df_trend(df, lead_time, data_window):
  dengue_trend=pd.DataFrame()
  dengue_trend['trend']=(df[-data_window-lead_time+1]-dengue_shift[-lead_time])/data_window
  return dengue_trend

def df_str_trend(df, weak, strong, data_window):
  strong_trend=pd.DataFrame()
  weak_label='ave'+str(weak)
  strong_label='ave'+str(strong)
  strong_trend['strong_trend']=(df[strong_label]-dengue_shift[weak_label])/data_window
  return strong_trend

# %%
dengue_trend=df_trend(dengue_process, LEAD_TIME, DATA_WINDOW)
strong_trend=df_str_trend(dengue_process, 2, DATA_WINDOW, DATA_WINDOW)

# %%
dengue_process=merge(dengue_process, dengue_trend)
dengue_process=merge(dengue_process, strong_trend)
dengue_process['dengue_std']=list(dengue_shift.std(axis=1))

# %%
dengue_process_norm=normaliser(dengue_process, 'trend', 'strong_trend')

# %%
combined_Data=merge(dengue_process_norm, combined_Data)
combined_Data.index=indexes

# %%
combined_Data.head()
# Out:
#                   -8        -9       -10       -11       -12       -13  \
# 2000-07-03 -1.015231 -0.987601 -0.980693 -1.008324 -1.008324 -1.035955
# 2000-07-10 -0.973785 -1.015231 -0.987601 -0.980693 -1.008324 -1.008324
# 2000-07-17 -1.015231 -0.973785 -1.015231 -0.987601 -0.980693 -1.008324
# 2000-07-24 -1.001416 -1.015231 -0.973785 -1.015231 -0.987601 -0.980693
# 2000-07-31 -0.966878 -1.001416 -1.015231 -0.973785 -1.015231 -0.987601
#
#                  -14       -15       -16       -17  ...  mean_temp78  \
# 2000-07-03 -1.022139 -0.980693 -1.042862 -0.987601  ...    -1.063192
# 2000-07-10 -1.035955 -1.022139 -0.980693 -1.042862  ...    -1.044305
# 2000-07-17 -1.008324 -1.035955 -1.022139 -0.980693  ...    -0.727000
# 2000-07-24 -1.008324 -1.008324 -1.035955 -1.022139  ...     0.474227
# 2000-07-31 -0.980693 -1.008324 -1.008324 -1.035955  ...    -0.545683
#
#             mean_temp84  mean_temp90  mean_temp96  mean_temp102  mean_temp108  \
# 2000-07-03    -1.187848    -0.424804    -0.458801     -0.073502     -0.575902
# 2000-07-10    -0.557015     0.005824    -0.436137     -0.651451     -0.326591
# 2000-07-17     0.402455    -0.930982    -0.677893     -0.194380     -0.013063
# 2000-07-24    -0.760997    -0.715667    -0.273707      0.353349      0.957739
# 2000-07-31    -0.591012    -0.500353     0.579995      1.040843      1.089950
#
#             mean_temp114  mean_temp120  dengue_actual  population
# 2000-07-03     -0.485243     -0.421027      -0.973785     4027887
# 2000-07-10     -0.319036      1.139057      -0.980693     4027887
# 2000-07-17      1.324151      0.836861      -0.973785     4027887
# 2000-07-24      1.108837      0.058708      -0.946154     4027887
# 2000-07-31     -0.013063     -0.243487      -0.897801     4027887
#
# [5 rows x 124 columns]

# %% [markdown]
# ### Adding year month data

# %%
combined_Data['year']=combined_Data.index.year
combined_Data['month']=combined_Data.index.month
combined_Data['trend']=list(dengue_trend['trend'])

# %%
combined_Data=normaliser(combined_Data, 'year','month', 'population')

# %%
def move_dengue_actual_to_back(df):
 a=pd.DataFrame(df['dengue_actual'])
 df.drop(['dengue_actual'], axis=1, inplace=True)
 df['dengue_actual']=a
 return df

# %%
df_normalised=move_dengue_actual_to_back(combined_Data)

# %% [markdown]
# ### Splitting the data
# Into X (features) and y (labels) and into training the testing sets

# %%
X=df_normalised.drop('dengue_actual', axis=1)
Y=pd.DataFrame(df_normalised['dengue_actual'])

# %%
def euclid_loss(a,b):
    return np.mean((a-b)**2)

def baseline(df):
  a=df[-LEAD_TIME]
  b=df['dengue_actual']
  return euclid_loss(a,b), list(a), list(b)

# %%
ratio=0.90
train_size=int(len(X)*ratio)
test_size=int(len(X)*(1-ratio));
print(test_size)
# Out:
# 100

# %% [markdown]
# ### Baseline prediction
# Involves shifting the graph `-LEAD_TIME` units and simply making predictions out of this shifted graph. This is the loss we will attempt to beat.

# %%
loss, pred, actual=baseline(df_normalised[-test_size:]); loss
# Out:
# 0.9056472100558683

# %%
len(X)
# Out:
# 1009

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

plt.plot(actual, label= 'Actual')
plt.plot(pred, label='Predictions')
plt.legend()
plt.show()

# %%
X_train=X[:train_size].values
X_test=X[train_size:len(X)].values
y_train=Y[:train_size].values
y_test=Y[train_size:len(Y)].values

# %%
a=set(list(X_train.flatten()))

# %%
b=set(list(X_test.flatten()))

# %%
b.issubset(a)
# Out:
# False

# %%
n=list(y_train.flatten())+list(y_test.flatten())

# %%
plt.plot(y_train)

# %%
plt.plot(n)

# %% [markdown]
# ### Data analysis
# Here we analyse correlation. We find that maximum rainfall is negatively correlated with dengue cases, as surprisingly, it could signal instances of flushing. Temperature is postiviely correlated with dengue. The bright yellow region in the top right signals that past weeks of dengue data is strongly correlated with the dengue cases in the week we are trying to predict.

# %%
df_normalised.corr().tail(3)
# Out:
#                      -8        -9       -10       -11       -12       -13  \
# year           0.289980  0.289885  0.289713  0.289425  0.289159  0.288411
# month          0.156252  0.164456  0.167633  0.170628  0.169859  0.164155
# dengue_actual  0.686176  0.649846  0.617188  0.581233  0.549548  0.518461
#
#                     -14       -15       -16       -17  ...  mean_temp90  \
# year           0.287349  0.286136  0.285082  0.283504  ...     0.278394
# month          0.155419  0.141938  0.127224  0.109867  ...     0.378597
# dengue_actual  0.490271  0.467866  0.450131  0.435136  ...     0.234250
#
#                mean_temp96  mean_temp102  mean_temp108  mean_temp114  \
# year              0.283863      0.278129      0.280576      0.280026
# month             0.383026      0.398525      0.423214      0.421680
# dengue_actual     0.230887      0.240552      0.238775      0.235017
#
#                mean_temp120  population      year     month  dengue_actual
# year               0.280144    0.978955  1.000000 -0.050692       0.293891
# month              0.397871   -0.043005 -0.050692  1.000000       0.055120
# dengue_actual      0.233402    0.285330  0.293891  0.055120       1.000000
#
# [3 rows x 126 columns]

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
plt.imshow(df_normalised.corr())
plt.show()

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape)
# Out:
# (908, 1, 125) (908, 1)

# %% [markdown]
# ### Defining our model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Flatten, Activation ,GRU
from tensorflow.keras.layers import LeakyReLU
# LeakyRelu=keras.layers.LeakyReLU(alpha=0.3)

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(1, X_train.shape[2]),return_sequences=True, activation='tanh'))
# model.add(LeakyReLU(alpha=0.3))

model.add(LSTM(128))
model.add(LeakyReLU(alpha=0.3))
model.add(Dropout(0.1))

model.add(Dense(98))
model.add(LeakyReLU(alpha=0.3))
model.add(Dropout(0.1))

# model.add(LSTM(64, activation=LeakyRelu, return_sequences=True))

model.add(Dense(64))
model.add(LeakyReLU(alpha=0.3))
model.add(Dropout(0.1))

model.add(Dense(32))
model.add(LeakyReLU(alpha=0.3))
model.add(Dropout(0.1))

model.add(Dense(1, activation=tf.nn.elu))
Adam=tf.keras.optimizers.Adam(lr=0.001, beta_1=0.99, beta_2=0.999, amsgrad=True, decay=0.0001)
SGD = tf.keras.optimizers.SGD(lr=0.003, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(optimizer=SGD,
              loss='mean_squared_error',)

# %% [markdown]
# ### Training our model

# %%
history=model.fit(X_train, 
                  y_train, 
                  epochs=1,
                  batch_size=64, 
#                   callbacks = [callback],
                  validation_data=(X_test, y_test), 
                  verbose=1,)
# Out:
# Train on 908 samples, validate on 101 samples
# 908/908 [==============================] - 0s 486us/sample - loss: 0.0659 - val_loss: 0.3252

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Testing loss')
plt.legend()
plt.show()

# %%
# model.save('epic-dengue-model090120')

# %% [markdown]
# ### Analysing our losses
# Note that the results of this section may differ for some people. We have managed to get `val-loss` down to about 0.2.

# %%
new_model=tf.keras.models.load_model(r'/Users/yipjh/Desktop/Projects/Predicting-Dengue-in-Singapore/Code and Model/epic-dengue-model090120')

# %%
p_test=new_model.predict(X_test)
# p_train=new_model.predict(X_train)

# %%
euclid_loss(p_test, y_test)
# Out:
# 0.14336832898397225

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

p=new_model.predict(X_test)
plt.plot(y_test, label='Actual')    
plt.plot(p, label='Model Predictions')
plt.legend()
plt.show()

# %%
correlation_test=pd.DataFrame()
correlation_train=pd.DataFrame()

# %%
correlation_test['predictions']=list(p_test.flatten())
correlation_test['actual']=list(y_test.flatten())
correlation_train['predictions']=list(p_train.flatten())
correlation_train['actual']=list(y_train.flatten())

# %%
corr_dict_test={}
for i in range(-10, 10):
    correlation_test[i]=correlation_test['predictions'].shift(i) #negative shift up. positive shift down
    _=pd.DataFrame()
    _['actual']=correlation_test['actual']
    _[i]=correlation_test[i]
    _=_.dropna()
    corr=_.corr().iloc[0, 1]
    corr_dict_test.update({i: corr})

# %%
correlation_test.head(20)
# Out:
#     predictions    actual       -10        -9        -8        -7        -6  \
# 0     -0.560566 -0.711293 -0.461102 -0.550201 -0.566465 -0.559694 -0.521006
# 1     -0.593943 -0.607677 -0.351777 -0.461102 -0.550201 -0.566465 -0.559694
# 2     -0.550595 -0.490246 -0.408664 -0.351777 -0.461102 -0.550201 -0.566465
# 3     -0.515298 -0.593862 -0.510158 -0.408664 -0.351777 -0.461102 -0.550201
# 4     -0.403057 -0.690570 -0.390152 -0.510158 -0.408664 -0.351777 -0.461102
# 5     -0.326125 -0.752739 -0.420611 -0.390152 -0.510158 -0.408664 -0.351777
# 6     -0.521006 -0.732016 -0.610495 -0.420611 -0.390152 -0.510158 -0.408664
# 7     -0.559694 -0.718200 -0.605940 -0.610495 -0.420611 -0.390152 -0.510158
# 8     -0.566465 -0.870170 -0.578995 -0.605940 -0.610495 -0.420611 -0.390152
# 9     -0.550201 -0.794185 -0.579833 -0.578995 -0.605940 -0.610495 -0.420611
# 10    -0.461102 -0.711293 -0.564515 -0.579833 -0.578995 -0.605940 -0.610495
# 11    -0.351777 -0.808000 -0.596644 -0.564515 -0.579833 -0.578995 -0.605940
# 12    -0.408664 -0.794185 -0.617498 -0.596644 -0.564515 -0.579833 -0.578995
# 13    -0.510158 -0.814908 -0.599667 -0.617498 -0.596644 -0.564515 -0.579833
# 14    -0.390152 -0.897801 -0.530078 -0.599667 -0.617498 -0.596644 -0.564515
# 15    -0.420611 -0.801093 -0.436762 -0.530078 -0.599667 -0.617498 -0.596644
# 16    -0.610495 -0.801093 -0.375648 -0.436762 -0.530078 -0.599667 -0.617498
# 17    -0.605940 -0.676754 -0.268424 -0.375648 -0.436762 -0.530078 -0.599667
# 18    -0.578995 -0.676754 -0.412138 -0.268424 -0.375648 -0.436762 -0.530078
# 19    -0.579833 -0.531693 -0.460040 -0.412138 -0.268424 -0.375648 -0.436762
#
#           -5        -4        -3  ...         0         1         2         3  \
# 0  -0.326125 -0.403057 -0.515298  ... -0.560566       NaN       NaN       NaN
# 1  -0.521006 -0.326125 -0.403057  ... -0.593943 -0.560566       NaN       NaN
# 2  -0.559694 -0.521006 -0.326125  ... -0.550595 -0.593943 -0.560566       NaN
# 3  -0.566465 -0.559694 -0.521006  ... -0.515298 -0.550595 -0.593943 -0.560566
# 4  -0.550201 -0.566465 -0.559694  ... -0.403057 -0.515298 -0.550595 -0.593943
# 5  -0.461102 -0.550201 -0.566465  ... -0.326125 -0.403057 -0.515298 -0.550595
# 6  -0.351777 -0.461102 -0.550201  ... -0.521006 -0.326125 -0.403057 -0.515298
# 7  -0.408664 -0.351777 -0.461102  ... -0.559694 -0.521006 -0.326125 -0.403057
# 8  -0.510158 -0.408664 -0.351777  ... -0.566465 -0.559694 -0.521006 -0.326125
# 9  -0.390152 -0.510158 -0.408664  ... -0.550201 -0.566465 -0.559694 -0.521006
# 10 -0.420611 -0.390152 -0.510158  ... -0.461102 -0.550201 -0.566465 -0.559694
# 11 -0.610495 -0.420611 -0.390152  ... -0.351777 -0.461102 -0.550201 -0.566465
# 12 -0.605940 -0.610495 -0.420611  ... -0.408664 -0.351777 -0.461102 -0.550201
# 13 -0.578995 -0.605940 -0.610495  ... -0.510158 -0.408664 -0.351777 -0.461102
# 14 -0.579833 -0.578995 -0.605940  ... -0.390152 -0.510158 -0.408664 -0.351777
# 15 -0.564515 -0.579833 -0.578995  ... -0.420611 -0.390152 -0.510158 -0.408664
# 16 -0.596644 -0.564515 -0.579833  ... -0.610495 -0.420611 -0.390152 -0.510158
# 17 -0.617498 -0.596644 -0.564515  ... -0.605940 -0.610495 -0.420611 -0.390152
# 18 -0.599667 -0.617498 -0.596644  ... -0.578995 -0.605940 -0.610495 -0.420611
# 19 -0.530078 -0.599667 -0.617498  ... -0.579833 -0.578995 -0.605940 -0.610495
#
#            4         5         6         7         8         9
# 0        NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN
# 4  -0.560566       NaN       NaN       NaN       NaN       NaN
# 5  -0.593943 -0.560566       NaN       NaN       NaN       NaN
# 6  -0.550595 -0.593943 -0.560566       NaN       NaN       NaN
# 7  -0.515298 -0.550595 -0.593943 -0.560566       NaN       NaN
# 8  -0.403057 -0.515298 -0.550595 -0.593943 -0.560566       NaN
# 9  -0.326125 -0.403057 -0.515298 -0.550595 -0.593943 -0.560566
# 10 -0.521006 -0.326125 -0.403057 -0.515298 -0.550595 -0.593943
# 11 -0.559694 -0.521006 -0.326125 -0.403057 -0.515298 -0.550595
# 12 -0.566465 -0.559694 -0.521006 -0.326125 -0.403057 -0.515298
# 13 -0.550201 -0.566465 -0.559694 -0.521006 -0.326125 -0.403057
# 14 -0.461102 -0.550201 -0.566465 -0.559694 -0.521006 -0.326125
# 15 -0.351777 -0.461102 -0.550201 -0.566465 -0.559694 -0.521006
# 16 -0.408664 -0.351777 -0.461102 -0.550201 -0.566465 -0.559694
# 17 -0.510158 -0.408664 -0.351777 -0.461102 -0.550201 -0.566465
# 18 -0.390152 -0.510158 -0.408664 -0.351777 -0.461102 -0.550201
# 19 -0.420611 -0.390152 -0.510158 -0.408664 -0.351777 -0.461102
#
# [20 rows x 22 columns]

# %%
corr_dict_train={}
for i in range(-10, 10):
    correlation_train[i]=correlation_train['predictions'].shift(i) #negative shift up. positive shift down
    _=pd.DataFrame()
    _['actual']=correlation_train['actual']
    _[i]=correlation_train[i]
    _=_.dropna()
    corr=_.corr().iloc[0, 1]
    corr_dict_train.update({i: corr})

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

x_vals=list(corr_dict_train.keys())
y_vals_test=list(corr_dict_test.values())
y_vals_train=list(corr_dict_train.values())

where=np.arange(0, 20)

plt.plot(y_vals_test, label='Correlation test')
plt.plot(y_vals_train, label='Correlation train')
plt.xticks(where,x_vals)
plt.legend()
plt.show()

# %%
corr_test=pd.DataFrame()
corr_test['correlation']=y_vals_test
corr_test.index=x_vals

# %%
corr_test.T

# %%
df_normalised
# Out:
#                   -8        -9       -10       -11       -12       -13  \
# 2000-07-03 -1.015231 -0.987601 -0.980693 -1.008324 -1.008324 -1.035955
# 2000-07-10 -0.973785 -1.015231 -0.987601 -0.980693 -1.008324 -1.008324
# 2000-07-17 -1.015231 -0.973785 -1.015231 -0.987601 -0.980693 -1.008324
# 2000-07-24 -1.001416 -1.015231 -0.973785 -1.015231 -0.987601 -0.980693
# 2000-07-31 -0.966878 -1.001416 -1.015231 -0.973785 -1.015231 -0.987601
# ...              ...       ...       ...       ...       ...       ...
# 2019-10-28  1.796202  2.224479  2.556049  2.549141  3.081034  3.115572
# 2019-11-04  1.215955  1.796202  2.224479  2.556049  2.549141  3.081034
# 2019-11-11  1.133063  1.215955  1.796202  2.224479  2.556049  2.549141
# 2019-11-18  1.015632  1.133063  1.215955  1.796202  2.224479  2.556049
# 2019-11-25  0.739324  1.015632  1.133063  1.215955  1.796202  2.224479
#
#                  -14       -15       -16       -17  ...  mean_temp90  \
# 2000-07-03 -1.022139 -0.980693 -1.042862 -0.987601  ...    -0.424804
# 2000-07-10 -1.035955 -1.022139 -0.980693 -1.042862  ...     0.005824
# 2000-07-17 -1.008324 -1.035955 -1.022139 -0.980693  ...    -0.930982
# 2000-07-24 -1.008324 -1.008324 -1.035955 -1.022139  ...    -0.715667
# 2000-07-31 -0.980693 -1.008324 -1.008324 -1.035955  ...    -0.500353
# ...              ...       ...       ...       ...  ...          ...
# 2019-10-28  3.405696  3.523126  3.032680  2.369541  ...     1.383295
# 2019-11-04  3.115572  3.405696  3.523126  3.032680  ...     1.092468
# 2019-11-11  3.081034  3.115572  3.405696  3.523126  ...     1.541417
# 2019-11-18  2.549141  3.081034  3.115572  3.405696  ...     1.550914
# 2019-11-25  2.556049  2.549141  3.081034  3.115572  ...     0.264525
#
#             mean_temp96  mean_temp102  mean_temp108  mean_temp114  \
# 2000-07-03    -0.458801     -0.073502     -0.575902     -0.485243
# 2000-07-10    -0.436137     -0.651451     -0.326591     -0.319036
# 2000-07-17    -0.677893     -0.194380     -0.013063      1.324151
# 2000-07-24    -0.273707      0.353349      0.957739      1.108837
# 2000-07-31     0.579995      1.040843      1.089950     -0.013063
# ...                 ...           ...           ...           ...
# 2019-10-28     1.166002      1.424490      1.452418      1.241551
# 2019-11-04     1.454090      1.513477      0.889997      0.805239
# 2019-11-11     1.483568      0.516282      1.190034      1.314438
# 2019-11-18     0.412529      1.170320      1.394592      1.085417
# 2019-11-25     1.292277      1.422653      1.046132      1.199891
#
#             mean_temp120  population      year     month  dengue_actual
# 2000-07-03     -0.421027   -1.527724 -1.728133  0.129213      -0.973785
# 2000-07-10      1.139057   -1.527724 -1.728133  0.129213      -0.980693
# 2000-07-17      0.836861   -1.527724 -1.728133  0.129213      -0.973785
# 2000-07-24      0.058708   -1.527724 -1.728133  0.129213      -0.946154
# 2000-07-31     -0.243487   -1.527724 -1.728133  0.129213      -0.897801
# ...                  ...         ...       ...       ...            ...
# 2019-10-28      0.461743    1.306597  1.657666  1.004219       0.608078
# 2019-11-04      1.341851    1.306597  1.657666  1.295888       1.063986
# 2019-11-11      1.141827    1.306597  1.657666  1.295888       1.160694
# 2019-11-18      1.274433    1.306597  1.657666  1.295888       1.512986
# 2019-11-25      0.400441    1.306597  1.657666  1.295888       1.243586
#
# [1009 rows x 126 columns]
